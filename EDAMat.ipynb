# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepuKun/Machine-Learning-Practice/blob/main/EDAMat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('salary_dataset.csv')

# %%
data.head()
# Out:
#    Experience Education           JobRole       Location  \
# 0           7       PhD       UX Designer        Seattle
# 1          19  Bachelor    Data Scientist        Seattle
# 2          10    Master    Data Scientist        Chicago
# 3           5       PhD  Business Analyst  San Francisco
# 4           8       PhD  Business Analyst         Boston
#
#                       Skills  Salary
# 0           Figma, UI Design   92813
# 1               Java, Spring  101104
# 2   Recruitment, HR Policies   89223
# 3  Project Management, Agile   85725
# 4           Figma, UI Design  107868

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Experience  71 non-null     int64
#  1   Education   71 non-null     object
#  2   JobRole     71 non-null     object
#  3   Location    71 non-null     object
#  4   Skills      71 non-null     object
#  5   Salary      71 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 3.5+ KB

# %%
data.shape
# Out:
# (71, 6)

# %%
data.size
# Out:
# 426

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     Experience Education            JobRole       Location  \
# 0            7       PhD        UX Designer        Seattle
# 1           19  Bachelor     Data Scientist        Seattle
# 2           10    Master     Data Scientist        Chicago
# 3            5       PhD   Business Analyst  San Francisco
# 4            8       PhD   Business Analyst         Boston
# ..         ...       ...                ...            ...
# 66          18       PhD        UX Designer        Seattle
# 67          11  Bachelor        UX Designer        Seattle
# 68          11    Master  Software Engineer       New York
# 69          14    Master   Business Analyst  San Francisco
# 70          20       PhD    Project Manager  San Francisco
#
#                        Skills  Salary
# 0            Figma, UI Design   92813
# 1                Java, Spring  101104
# 2    Recruitment, HR Policies   89223
# 3   Project Management, Agile   85725
# ...

# %%
data.isnull()
# Out:
#     Experience  Education  JobRole  Location  Skills  Salary
# 0        False      False    False     False   False   False
# 1        False      False    False     False   False   False
# 2        False      False    False     False   False   False
# 3        False      False    False     False   False   False
# 4        False      False    False     False   False   False
# ..         ...        ...      ...       ...     ...     ...
# 66       False      False    False     False   False   False
# 67       False      False    False     False   False   False
# 68       False      False    False     False   False   False
# 69       False      False    False     False   False   False
# 70       False      False    False     False   False   False
#
# [71 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Experience    0
# Education     0
# JobRole       0
# Location      0
# Skills        0
# Salary        0
# dtype: int64

# %%
#Univariate Analysis
#Distribution of employees by salary

# %%
plt.figure(figsize=(8,6))
sns.histplot(data['Salary'], bins = 10, kde= True)
plt.title('Distribution of Employees by Salary')
plt.xlabel('Salary')
plt.ylabel('Number of Employes')
plt.show()
